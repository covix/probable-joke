# %%
import os
import numpy as np

from matplotlib import pyplot as plt
from scipy.ndimage.filters import gaussian_filter1d
from scipy.signal import savgol_filter

# %matplotlib notebook
# %matplotlib notebook

# %%
def load_video_frames(input_folder):
    l = []
    files = sorted(os.listdir(input_folder))

    for j in range(0, len(files)):
        fname = os.path.join(
            input_folder, files[j])
        l.append(plt.imread(fname))

    return np.array(l)


def load_videos(input_folder):
    d = {}
    for i in os.listdir(input_folder):
        if os.path.isdir(os.path.join(input_folder, i)):
            print(i)
            d[i] = []
            files = sorted(os.listdir(os.path.join(input_folder, i)))

            for j in range(0, len(files)):
                fname = os.path.join(
                    input_folder, i, files[j])
                d[i].append(plt.imread(fname))

    return d

# %%
input_folder = '/media/schenock/01D1B41ED893D2C0/Projects/probable-joke/data/asl'

mse = []

count = 0

for video_folder in os.listdir(input_folder):
    
    print(video_folder)

    frames = load_video_frames(os.path.join(input_folder, video_folder))
    
    mse.append(analyse_MSE(frames, window=5, frame_step=5))

    count=count+1
    if count>5:
        break

print("Maximum mse: ", max_value(mse))
print("Minimum mse: ", min_value(mse))
        
# plt.figure()
# plt.title("Mean differences MSE (w:{}, step:{})".format("window", "frame_step"))
# for error in mse:
#     plt.plot(mse, 'o')
# Out:
# 07-M-09-D-comp
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-108a4ad22fb3> in <module>()
#      11     frames = load_video_frames(os.path.join(input_folder, video_folder))
#      12
# ---> 13     mse.append(analyse_MSE(frames, window=5, frame_step=5))
#      14
#      15     count=count+1
#
# NameError: name 'analyse_MSE' is not defined

# %%
features_01 = np.loadtxt("/media/schenock/01D1B41ED893D2C0/Projects/probable-joke/data/features/03-M-04-C-comp_features.csv")


features_01.shape
# Out:
# (128, 1024)

# %%
correlation_coeffs = np.corrcoef(features_01)

plt.imshow(correlation_coeffs, interpolation="None", cmap='Greens')
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="639.8499802953507">

# %%
features_folder = "/media/schenock/01D1B41ED893D2C0/Projects/probable-joke/data/features"

th = 0.9

# first frame
first_frame = 0

# last frame
last_frame = len(correlation_coeffs) - 1

count = 0
for f in os.listdir(features_folder):
    features = np.loadtxt(os.path.join(features_folder, f))
    correlation_coeffs = np.corrcoef(features)
  
    ref_frame = len(correlation_coeffs[0]) - 1
    
    print(np.std(correlation_coeffs[ref_frame]))
#   gauss_smooth = gaussian_filter1d(correlation_coeffs[0], sigma=9)
#   sav_smooth = savgol_filter(correlation_coeffs[0], window_length = 9, polyorder = 0)
     
#     mini = min(correlation_coeffs[ref_frame])
#     middle = np.where(correlation_coeffs[ref_frame] == mini)

    middle_value = (len(correlation_coeffs) - 1) / 2
    index_middle = int(middle_value)
    
    maxi = max(correlation_coeffs[ref_frame])
    mini = min(correlation_coeffs[index_middle:])
    
    cut = (((maxi - mini) / 2 ) + mini) * 1.1
    
    
    plt.figure()
    plt.suptitle(f)
    above = np.where(correlation_coeffs[ref_frame] > cut)[0]
    below = np.where(correlation_coeffs[ref_frame] < cut)[0]
    print("Above: ", above)
    
    
    above_left = [frame for frame in above if frame < index_middle]
    above_right = [frame for frame in above if frame > index_middle]
    print("Above right: ", above_right )
    print("Above right: ", above_right )
    
    if ref_frame == 0:
        cut_frame = max(above_left)
    else:
        cut_frame = min(above_right)


    
    plt.plot(above, correlation_coeffs[ref_frame][above], "go-", alpha = 0.3)
    
    plt.plot(below, correlation_coeffs[ref_frame][below], "go-", alpha = 1)
 
    plt.axhline(y = cut)
    
    plt.axvline(x = middle_value)

    #print("Cut from: ", cut_frame)
    print("Cut to: ", cut_frame)
# Out:
# 0.0803239235119
# <div id='7a666355-c077-4bb3-85b8-14857039728f'></div>
# Above:  [65 67 68]
# Above right:  [65, 67, 68]
# Above right:  [65, 67, 68]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-9b94fb97428f> in <module>()
#      55     plt.plot(below, correlation_coeffs[ref_frame][below], "go-", alpha = 1)
#      56
# ---> 57     plt.axhline(y = cut)
#      58
#      59     plt.axvline(x = middle_value)
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py in axhline(y, xmin, xmax, hold, **kwargs)
#    2541                       mplDeprecation)
#    2542     try:
# -> 2543         ret = ax.axhline(y=y, xmin=xmin, xmax=xmax, **kwargs)
#    2544     finally:
#    2545         ax._hold = washold
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_axes.py in axhline(self, y, xmin, xmax, **kwargs)
#     724         self._process_unit_info(ydata=y, kwargs=kwargs)
#     725         yy = self.convert_yunits(y)
# --> 726         scaley = (yy < ymin) or (yy > ymax)
#     727
#     728         trans = self.get_yaxis_transform(which='grid')
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
def find_nearest(array,value):
    idx = (np.abs(array-value)).argmin()
    return array[idx]
